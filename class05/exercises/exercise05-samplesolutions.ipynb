# %% [markdown]
# # Python Crash Course - Exercise 05
#
# Exercises are split up into two parts - a theoretical and a practical part.

# %% [markdown]
# # Part A: Theoretical questions

# %% [markdown]
# ## a) Lists
# Discuss the following questions from the book, Chapter 4: Question 1--5:
# * What is `[]`? <font color ='orange'>a list</font>
# * How would you assign the value `'hello'` as the third value in a list stored in a variable named `spam`? (Assume spam contains `[2, 4, 6, 8, 10]`.) <font color ='orange'>spam[2] = 'hello</font>
# * For the following three questions, letʼs say spam contains the list `['a', 'b', 'c', 'd']`.
#     * What does `spam[int(int('3' * 2) // 11)]` evaluate to? <font color ='orange'> d </font>
#     * What does `spam[-1]` evaluate to? <font color ='orange'> d </font>
#     * What does `spam[:2]` evaluate to? <font color ='orange'> ['a', 'b']</font>

# %% [markdown]
# For the following questions, letʼs say `lasagna` contains the list `[3.14, 'cat', 11, 'cat', True]`.
# * What does `lasagna.index('cat')` evaluate to?  <font color ='orange'>1 </font>
# * What does `lasagna.append(99)` make the list value in `lasagna` look like?  <font color ='orange'> [3.14, 'cat', 11, 'cat', True, 99]</font>
# * What does `lasagna.remove('cat')` make the list value in `lasagna` look like?  <font color ='orange'> [3.14, 11, 'cat', True]</font>
# * What are the operators for list concatenation and list replication?  <font color ='orange'> + and * </font>

# %% [markdown]
# ## b) List slicing
# What are the results of the following operations?
# * `['a', 'b', 'c', 'd'][1]` <font color ='orange'> b </font>
# * `['a', 'b', 'c', 'd'][0:4]` <font color ='orange'> ['a', 'b', 'c', 'd'] </font>
# * `['a', 'b', 'c', 'd'][:2]` <font color ='orange'> ['a', 'b'] </font>
# * `['a', 'b', 'c', 'd'][3:]` <font color ='orange'> ['d'] </font>

# %% [markdown]
# ## c) Strings
# * What do the following expressions evaluate to?
# ```python
# 'Hello, world!'[1] # H
# 'Hello, world!'[0:5] # Hello
# 'Hello, world!'[:5] # Hello
# 'Hello, world!'[3:] # lo, world
# ```
#
# * What do the following expressions evaluate to?
# ```python
# 'Hello'.upper() # HELLO
# 'Hello'.upper().isupper() # True
# 'Hello'.upper().lower() # hello
# ```
#
# * What do the following expressions evaluate to?
# ```python
# 'Remember, remember, the fifth of November.'.split() # ['Remember', 'remember', 'the', 'fifth', 'of', 'November.']
# '-'.join('There can be only one.'.split()) # 'There-can-be-only-one.'
# ```

# %% [markdown]
# ## Practising the basics
# Go through [Python Lists](https://www.w3schools.com/python/exercise.asp?filename=exercise_lists1), [Python Functions](https://www.w3schools.com/python/exercise.asp?filename=exercise_functions1), and [Python Modules](https://www.w3schools.com/python/exercise.asp?filename=exercise_modules1) exercises.

# %% [markdown]
# # Part A: Practical challenges
# There are 4 practical tasks you have to solve.

# %% [markdown]
# ## Task 1: Pizzas!
# 1. Think of the names of your three favorite pizzas.
#     * Store these pizza names in a list. Find an appropriate name for the list yourself.
#     * Use a `for` loop to print the name of each pizza one by one.
# <br/><br/>
#
# 3. Modify your `for` loop to print a whole sentence instead of just printing the name of the pizza. For each pizza, you should have one line of output containing a simple statement like _I like pepperoni pizza_ (if the list contains the element `'pepperoni'`).
#
# 4. Add a line at the end of your program, outside the `for` loop, that states how much you like pizza. This
# means that the output of your program should consist of three or more lines about the kinds of pizza
# you like and then an additional sentence, such as _I really love pizza!_
#
# __What you need to know__: Building and looping through a list, string concatenation

# %%
# your code here
pizzas = ['Pepperoni', 'Potato', 'Napoli']
for pizza in pizzas:
    print('I like ' + pizza + ' pizza')
print('I really like pizza!')

# %% [markdown]
# ## Task 2: Using lists to format food
#
# Say you have a list value like this:
# ```python
# food = ['apples', 'bananas', 'tofu', 'salmon']
# ```
#
# Write a function that takes a list value as an argument and returns a string with all the items separated by a comma and a space, with __and__ inserted before the last item. For example, passing the previous `food` list to the function would return the string `'apples, bananas, tofu, and salmon'`. Of course, your function should be able to work with any list value passed to it.
#
# __Hint:__ Start by defining a variable that is assigned to an empty string `""`. Using a loop and string concatenation, build the comma-separated part of the string (you have to ignore the last word!), then add the last word with __and__ in front of it. Remember that the length of a list `food` can be found by using len(food).
#
# What you need to know: Looping through lists, string concatenation.
#
# __Here is a template to get you started:__

# %%
# your code here
def format_list(food):
    result = ""
    # convert the list item by item by adding it to the result variable
    return result

food = ['apples', 'bananas', 'tofu', 'salmon']
print(format_list(food)) # is supposed to print 'apples, bananas, tofu, and salmon'

# %%
def format_list(l):
    result = ""
    if len(l) == 0: # empty list
        return result
    if len(l) == 1: # only one element in list
        return l[0]
    
    for element in l[:-1]: # all except last element
        result = result + element + ", "
    result = result + "and " + l[-1]
    return result


food = ['apples', 'bananas', 'tofu', 'salmon']
print(format_list(food))

# %% [markdown]
# ## Task 3: At the supermarket
# ```python
# shopping_list = ["onions", "milk", "bread", "butter", "rice", "vinger", "oil", "pineapple", "onions", "salt", "chicken", "parsley", "mint","sugar", "onions"]
#
# snack_list = ['chips', 'crackers', 'Matador Mix XXL']
# ```
# Above, we have defined a shopping list, and a snack list. Use list methods and various operators to:
# * add `"oranges"` to the shopping list
# * add the snacks list to the shopping list (use `+` or `+=`, not `.append()`!)
# * find out at which list position is the `"chicken"`
# * remove `"butter"` from the shopping list (turns out we already have that at home)
# * count how many times does `"onions"` appear on the list
# * sort the shopping list alphabetically, and print it out
# * make sure that every item appears only once by converting the list to a `set`, and saving it into the variable `shopping_set`.
# * how many _unique_ items are in our shopping set now?

# %%
# your code here
shopping_list = ["onions", "milk", "bread", "butter", "rice", "vinger", "oil", "pineapple", "onions", "salt", "chicken", "parsley", "mint","sugar", "onions"]

snack_list = ['chips', 'crackers', 'Matador Mix XXL']

# add oranges
shopping_list.append("oranges")

# add snacks
shopping_list += snack_list

# where is the chicken?
print(shopping_list.index("chicken"))

# remove the butter
print(shopping_list.remove("butter"))

# Count how many times "onions" is on the list
print(shopping_list.count("onions"))

# sort the list alphabetically, and print it out
shopping_list.sort()
print(shopping_list)

shopping_set = set(shopping_list)
shopping_set

print(len(shopping_set))

# %% [markdown]
# ## Task 4: At the ice cream shop
# You are the owner of an ice cream shop. Your employee who sells the ice cream is a data science student! They decided to write down all ice cream orders of the day in Python. Use `list/set/tuple` methods to find out:
# * How many ice creams have been sold today?
# * How many unique ice creams have been sold today?
#
# > Note: the orders are saved as tuples - and for the sake of this exercise, we assume that for ice cream
# uniqueness, the order matters: `('yoghurt', 'mint')` is not the same as `('mint', 'yoghurt')`
#
#
# * How many customers have ordered the same flavor twice? (e.g. `("banana", banana")`)
# * Which was the most popular ice cream combination? (There are several ways of finding out. __Hint: it has been sold five times!)__
# * How many different individual ice cream flavours have been sold today? (i.e. individual flavours, `mint`, `cookie`, etc.)

# %%
# all sold ice creams today
icecream_sold = [ ('yoghurt', 'mint'), ('cookie', 'cookie'), ('caramel', 'yoghurt'),
                  ('yoghurt', 'straciatella'), ('caramel', 'straciatella'),('vanilla', 'yoghurt'),
                  ('hazelnut', 'banana'), ('straciatella','straciatella'), 
                  ('cookie', 'cookie'), ('cookie', 'caramel'),('banana', 'straciatella'),
                  ('cheesecake', 'cookie'), ('chocolate','chocolate'), ('mint', 'hazelnut'),
                  ('hazelnut', 'cheesecake'), ('caramel', 'vanilla'), ('yoghurt', 'mint'),
                  ('cheesecake','vanilla'), ('chocolate', 'cookie'), ('mint', 'strawberry'),
                  ('cookie','strawberry'),('hazelnut', 'vanilla'), ('yoghurt', 'strawberry'),
                  ('strawberry','chocolate'), ('cheesecake', 'cookie'), ('straciatella', 'vanilla'),
                  ('caramel', 'banana'), ('mint', 'straciatella'), ('caramel','strawberry'),
                  ('cookie', 'strawberry'), ('caramel', 'yoghurt'), ('strawberry', 'mint'),
                  ('mint', 'hazelnut'), ('banana', 'hazelnut'), ('straciatella', 'banana'),
                  ('mint', 'straciatella'), ('cheesecake', 'chocolate'), ('mint', 'yoghurt'),
                  ('cookie','banana'), ('cheesecake', 'mint'), ('banana', 'straciatella'),
                  ('mint', 'straciatella'), ('straciatella', 'straciatella'), ('cookie', 'mint'),
                  ('cookie', 'straciatella'), ('banana', 'caramel'), ('mint', 'cheesecake'),
                  ('chocolate', 'banana'), ('cheesecake','vanilla'), ('vanilla', 'yoghurt'),
                  ('hazelnut', 'yoghurt'), ('hazelnut', 'cookie'), ('strawberry', 'cookie'),
                  ('yoghurt','cheesecake'), ('cheesecake', 'banana'), ('vanilla', 'hazelnut'),
                  ('cookie', 'strawberry'), ('mint', 'straciatella'), ('cheesecake','vanilla'),
                  ('cookie', 'strawberry'), ('cookie', 'strawberry')]

# %%
# your code here
# How many ice creams have been sold today?
len(icecream_sold)

# %%
# How many UNIQUE ice creams have been sold today?
len(set(icecream_sold))

# %%
# How many customers have ordered the same flavour twice?
number_of_doubles = 0
list_of_doubles = []
for icecream in icecream_sold:
    if icecream[0]==icecream[1]:
        number_of_doubles += 1
        list_of_doubles.append(icecream)
print("orders with twice the same flavor:", list_of_doubles)
print("Number of orders with twice the same flavor:", number_of_doubles)

# %%
# Which was the most popular ice cream combination? (if we already know that it has been sold exactly 5 times)
for icecream in icecream_sold:
    number_of_orders = icecream_sold.count(icecream)
    if number_of_orders == 5:
        print(number_of_orders, icecream)

# %%
# Which was the most popular ice cream combination? (option 2 - without using the "sold 5 times" information)
list_of_counts = []
for icecream in icecream_sold:
    # for each icecream combination, count the number of times it appears in the list
    number_of_orders = icecream_sold.count(icecream)
    # ... and append that number to our list_of_counts:
    list_of_counts.append(number_of_orders)
print(list_of_counts)

# %%
# list_of_counts contains the number of times each ice cream combination appears on the list.
# find the max on that list:
max_number = max(list_of_counts)
print(max_number)

# %%
# find the index of the first appearance of 5 on that list:
first_max_index = list_of_counts.index(5)

# %%
# find out what ice cream it refers to:
print(icecream_sold[first_max_index])

# %%
# How many different ice cream flavours have been sold?
flavors_list = [] # initiate an emtpy list
for icecream in icecream_sold:
    flavors_list.append(icecream[0])
    flavors_list.append(icecream[1])
    # append both the first and the second item in the icecream tuple to the list
flavors_set = set(flavors_list) # make a set to obtain unique values from the list
print("Number of unique flavors:", len(flavors_set))
print("List of unique flavors:", flavors_set)
