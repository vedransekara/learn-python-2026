# %% [markdown]
# # Python Crash Course - Exercise 02
#
# __Goal: Solve the (8 + 1) taks!__

# %% [markdown]
# ## Task 0: Using Jupyter Notebook
#
# Make sure you can tick all items off this list (will be demonstrated in class):
#
# * I know how to **open** a Jupyter notebook
# * I know how to **create** a new Jupyter notebook
# * I know how to create **cells** of type `code` and `markdown`
# * I know how to **move a cell** up or down
# * I know how to **run** one single cell
# * i know how to **run all** cells at once
# * I know how to **clear** the output of one cell
# * I know how to **clear all**  cell output at once
# * I know how to **restart** the notebook kernel
# * I know how to **write and format** text in markdown
#
# For more resources, check these links:
# * A quickstart Jupyter Notebook tutorial from [Datacamp](https://www.datacamp.com/tutorial/tutorial-jupyter-notebook)
# * A more detailed Jupyter Notebook tutorial from [DataQuest](https://www.dataquest.io/blog/jupyter-notebook-tutorial/)
# * Official [Project Jupyter documentation](https://docs.jupyter.org/en/latest/)
# * Basic syntax in [Markdown](https://www.markdownguide.org/basic-syntax/)

# %% [markdown]
# ## Task 1: Using Python as a calculator
#
# Use Python to compute the values of `x`, `y`, and `z`. Print out the value of `z`.
#
# $x = 3^{(4-1)} + \frac{16 * (5^{0} - 2)}{2 * 4}$
#
# $y = x^{2} + (3-x)*x$
#
# $z = \frac{y}{x} $
#
# Your code should look something like this:
# ```python
# x = ...
# y = ...
# z = ...
# print(z)
# ```

# %% [markdown]
# **Solve Task 1:**

# %%
# YOUR CODE HERE
x = 3 ** (4-1) + 16 * (5**0 -2)/(2*4)
y = x**2 + (3-x)*x
z = y / x
print(z)

# %% [markdown]
# ***
# ## Task 2: Understanding how logical operators, booleans, and comparion operators work
# This task has 7 subquestions (Q1-Q9)
# ### Q1: What are the two values of the Boolean data type? How do you write them?

# %%
# your answer here
# True and False

# %% [markdown]
# ### Q2: What are the three Logical operators

# %%
# your answer here
# and, or, not

# %% [markdown]
# ### Q3: Write out the thruth tabels of each Logical operator (that is, every possible combination of Boolean values (`True`/`False`) for each operator (`and`,`or`,`not`) and what they evaluate to).
#
# Hint:
#
# __For the operator `and`__
# * `True and True` evaluates to `True`
# * `True and False` evaluates to `False`
# * `False and True` evaluates to `False`
# * `False and False` evaluates to `False`
#
# __For the operator `or`__
# * `True or True` evaluates to `True`
# * `True or False` evaluates to `True`
# * `False or True` evaluates to `True`
# * `False or False` evaluates to `False`
#
# __For the operator `not`__
# * not `True` evaluates to `False`
# * not `False` evaluates to `True`

# %%
# your answer here
# see above

# %% [markdown]
# ### Q4: What do the following expressions evaluate to?
# * `(5 > 4) and (3 == 5)` ->  `False`
# * `not (5 > 4)` -> `False`
# * `(5 > 4) or (3 == 5)` -> `True`
# * `not ((5 > 4) or (3 == 5))` -> `False`
# * `(True and True) and (True == False)` -> `False`
# * `(not False) or (not True)` -> `True`

# %%
# your answer here
# see above

# %% [markdown]
# ### Q5: What are the six comparison operators?

# %%
# your answer here
# ==, !=, <, >, <=, >=

# %% [markdown]
# ### Q6: What is the difference between the equal to operator and the assignment operator?

# %%
# your answer here
# == is the equal to operator. It asks whether two values are the same
# = is the assignment operator. It assigns a value to a variable. It puts the value on the right into the variable on the left
# i.e. variable = value

# %% [markdown]
# ### Q7: Explain what a condition is and where you would use one.

# %%
# your answer here
# Conditions always evaluate down to a Boolean value, True or False. A flow control statement
# decides what to do based on whether its condition is True or False, and almost every flow
# control statement uses a condition.

# %% [markdown]
# ***
# ## Task 3: Getting familiar with Booleans
#
# First, find out what happens if you use mathematical operators on the booleans `True` and `False`. Can you formulate a general rule? For example, you can test the following expressions:
#
# ```python
# True + True + True
# True * 7.5
# False + 9
# False - 5
# True / 4
# ... # and so on - try out what you like!
# ```
#
# Next, let's remind ourselves of what the boolean value of objects is. Can you predict what the Boolean value will be for the following expressions?
#
# ```python
# bool(28)
# bool(-5.5)
# bool(0)
# bool("True")
# bool("abracadabra")
# bool("") # note: "" is an empty string object
# bool("false")
# # implement the code yourself to check if you were right!
# ```

# %% [markdown]
# **Solve Task 2:**

# %%
# YOUR CODE HERE
True + True + True # evaluates to 3

True * 7.5 # evaluates to 7.5

False + 9 # evaluates to 9

False - 5 # evaluates to -5

True / 4 # evaluates to 0.25

# %% [markdown]
# **Insert** your general rule about doing maths with Booleans here
#
# > In general, Python treats `True` as the number `1`, and `False` as the number `0`

# %%
# YOUR CODE HERE - truth value of objects
bool(28) # evaluates to True

bool(-5.5) # evaluates to True

bool(0) # evaluates to False

bool("True") # evaluates to True

bool("abracadabra") # evaluates to True

bool("") # evaluates to False

bool("false") # evaluates to True
# Note: the expression above evaluates to True because it is understood as non-empty string

# %% [markdown]
# **Insert** your general rule about the boolean value of objects here
#
# > In Python, non-empty objects and all numbers except `0` have the boolean value of `True`, and empty objects and the number `0` have the boolean value of `False`.

# %% [markdown]
# ***
# ## Task 4: Casting (converting) data types
#
# A quick recap on data types and casting:
# * to **check** for the data type of the object `x`, use `type(x)`
# * to **cast** the object `x` to a data type, use `int() float() str() bool()`
# As in the exercise before, try to predict what the output of each statement will be; then implement it to check if you were correct.
#
# ```python
# ### checking the type of an object
# type(3)
# type(1+2)
# type(1+2.0)
# type(9/3)
# type("3")
#
# ### int/str/bool to float
# float(8)
# float("45.5")
# float(False)
#
# ### int/float/bool to str
# str(1)
# str(3.5)
# str(True)
#
# ### float/str/bool to int
# int(4.0)
# int("5")
# int(False)
#
# ### ... and some funky combinations:
# str(int(4.5))
# str(bool(9))
# bool(float(0))
# float(int(str(7)))
# ```
#
# What happens if you convert decimal numbers of type `float` to `int`? Can you formulate a general rule? For example, you can test on the following expressions:
# ```python
# ### decimals to int
# int(8.9)
# int(0.999999)
# int(1.000007)
# ```

# %% [markdown]
# **Solve Task 3**

# %%
# YOUR CODE HERE - checking the type of an object
type(3) # int
type(1+2) # still int 
type(1+2.0) # float
type(9/3) # float
type("3") # str

# %%
# YOUR CODE HERE - int/str/bool to float
float(8) # 8.0
float("45.5") # 45.5
float(False) # 0.0

# %%
# YOUR CODE HERE - int/float/bool to str
str(1) # '1'
str(3.5) # '3.5'
str(True) # 'True'

# %%
### YOUR CODE HERE - float/str/bool to int
int(4.0) # 4
int("5") # 5
int(False) # 0

# %%
# YOUR CODE HERE - funky combinations:
str(int(4.5)) # '4'
str(bool(9)) # 'True'
bool(float(0)) # False
float(int(str(7))) # 7.0

# %%
# YOUR CODE HERE - decimals to int:
int(8.9) # 8
int(0.999999) # 0
int(1.000007) # 1

# %% [markdown]
# **Insert** your general rule about converting decimals to int here
#
# > Converting a decimal number `x` to int with Python will returns the greatest integer less than or equal to `x` (in math its called the floor function).

# %% [markdown]
# ***
# ## Task 5: Combining strings
#
# A quick recap:
# * You can use the `+` operator to concatenate strings
# * You can use the `*` operator to "multiply" a string by an integer x, i.e. to repeat it x times
# * If you want to concatenate strings with other data types, you need to cast them to `str` first
#
# ```python
# a = "misc"
# b = "ellane"
# c = "ous"
# # concatenate the variables a, b and c to obtain the word "miscellaneous" printed out
#
# x = "i am"
# y = "very"
# z = "angry"
# # concatenate / multiply the variables x, y and to obtain the sentence "i am very very very very angry".
# # insert spaces if needed (within the variable definition, or like so: " ")
#
# myint = 1
# mybool = True
# mystr = "Love"
# # combine the variables myint, mybool and mystr to obtain the string "1 True Love". Add white spaces if needed.
# ```

# %% [markdown]
# **Solve Task 4**

# %%
# YOUR CODE HERE
# miscellaneous
a = "misc"
b = "ellane"
c = "ous"
d = a + b + c
print(d)

# %%
# i am very very very very angry
x = "i am " # adding a whitespace at the end of the string
y = "very " # adding a whitespace at the end of the string
z = "angry"

fullsentence = x + 4*y + z
print(fullsentence)

# %%
# 1 True Love
myint = 1
mybool = True
mystr = "Love"

fullstatement = str(myint) + " " + str(mybool) + " " + mystr
print(fullstatement)
# print(myint, mybool, mystr) # (quick solution, but does not produce a string!)

# %% [markdown]
# ***
# ## Task 6:
#
# ### Q6.1 What is the output of the below Python program.
#
# ```python
# spam = 0
# if spam == 10:
#     print('eggs')
#     if spam > 5:
#         print('bacon')
#     else:
#         print('ham')
#     print('spam')
# print('spam')
# ```

# %%
# your answer here
# 'spam'

# %% [markdown]
# ### Q6.2 What happens if the first line is replaced by `spam = 10`.

# %%
# your answer here
'eggs'
'bacon'
'spam'
'spam'

# %% [markdown]
# ### Q6.3 Can the following output be produced by the program?
#
# ```
# eggs
# ham
# spam
# spam
# ```

# %%
# your answer here
# No, since for it to print eggs, spam would have to be = 10, which means, when you enter the first
# block of code with spam == 10, if spam > 5 will always be True and thus print bacon as well. If the
# first condition would evaluate to False, you would never reach eggs nor bacon.

# %% [markdown]
# ***
# # Task 7: Coding task 1
# What does the following program do?
# For this exercise you do not have to type in the code or run it. You can of course do it, but try not to.
# The goal is for you to explain what each line of the following program does. Imagine someone
# runs the code, what do you think will be the output given `guess = 13.5`?
#
# ``` python
# secret_number = 42
# guess = ???
# if secret_number == guess:
#     print("Correct!")
# elif guess >= 1 and guess <= 100 and secret_number < guess:
#     print("Wrong! My number is smaller.")
# elif guess >= 1 and guess <= 100 and secret_number > guess:
#     print("Wrong! My number is larger.")
# else:
#     print("I asked for a number between 1 and 100, not " + str(guess) + ".")
# ```

# %%
# your answer here
"Wrong! My number is larger."

# %% [markdown]
# ***
# # Task 8: Coding task 2
#
# A person goes through many different stages in his/her life, usually defined as follows:
# * If the person is less than 2 years old, the person is a `baby`.
# * If the person is at least 2 years old but less then 4, the person is a `toddler`.
# * If the person is at least 4 years old but less than 13, the person is a `kid`.
# * If the person is at least 13 years old but less than 20, the person is a `teenager`.
# * If the person is at least 20 years old but less than 65, the person is an `adult`.
# * If the person is 65 years or older, the person is an `elder`.
#
# Write a Python program that uses a variable `age` to subsequently print the current stage of a persons life on the screen.
# First, translate the scheme above into a flow chart.
# Next, implement the flow chart with a Python program.
# Try to solve the problem using an if/elif/else statement.
# Discuss if the order of elif statements is important for the correctness of your program.
#
# Run the code with values `age = 1.999`, `age = 4`, `age = 20`, and `age = True`

# %%
# your answer here
age = ???
if age < 2:
    print('Baby')
elif age < 4:
    print('Toddler')
elif age < 13:
    print('Kid')
elif age < 20:
    print('Teenager')
elif age < 65:
    print('Adult')
else:
    print('Elder')

# %%
# age = 1.999 -> 'Baby'
# age = 4 -> 'Kid'
# age = 20 -> Adult
# age = True -> 'Baby'
