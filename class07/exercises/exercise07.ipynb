# %% [markdown]
# # Python Crash Course - Exercise 07
#
# __Todays sheet has 5 tasks, to solve them, use the provided data files.__

# %% [markdown]
# # Part 1: Dictionaries
# Write a function called `csv2dict` that takes a filename as the input, corresponding to a csv file with a header (first line) of an arbitrary number of variable names. The function should load the entire file into a dictionary, where keys are from the header and values are lists of values for the corresponding column in the file. The function should return (not print) this dictionary.
#
# A csv file is a file of lines with values separated by comma. If you develop your code on your computer, it can be a good idea to generate your own input csv file for testing. Assume you have the following example csv file called `test1.csv` containing:
#
# ```
# name,age,eye_color,nationality
# noah,24,brown,brazilian
# astrid,21,green,singapore
# aske,19,brown,brazilian
# ```
# In this example, the function call `csv2dict("test1.csv")` should then return this dictionary:
# ```
# {'name': ['noah', 'astrid', 'aske'],
# 'age': ['24', '21', '19'],
# 'eye_color': ['brown', 'green', 'brown'],
# 'nationality': ['brazilian', 'singapore', 'brazilian']}
# ```

# %%
# your code here

# %% [markdown]
# # Task 2: Regular expressions
# In the file `article.txt`, we provide the text of this [Guardian article](https://www.theguardian.com/commentisfree/2023/jul/12/progress-climate-european-greenlash-populist-right) by Nathalie Tucci. Let's say we are VERY interested in all the numbers that she used in the article.
#
# Your tasks:
# * `.read()` in the text file
# * find all the numbers (of one or more characters, with the regex `"\d+"`) mentioned in the text, and print them out
# * `.split()` the text into separate sentences using `'. '` as  seperator
# * loop through the sentences, `.append()`'ing only the ones that contain numbers to a list
# * __Additional challenge 🙀:__ try to write this list to a text file, so that every line in the text file is a sentence (with a number) from the article

# %%
# your code here
import re

# %% [markdown]
# # Task 3: Regular expressions
# Write a function `strong_password` that uses regular expressions to make sure the password string it is
# passed is strong. It returns `True` if the password is strong, and `False` otherwise.
#
# A strong password is defined as one that is at least eight characters long, contains both uppercase and lowercase characters, and has at least one digit. You may need to test the string against multiple regex patterns to validate its strength.
#
# Use your function to print every password that is __not__ strong in `passwords.tx`.
#
# Try to achieve the same functionality with Python's string methods. To that end, the following lists are going to be helpful:
#
# ```
# import string
# print(list(string.ascii_lowercase))
# print(list(string.ascii_uppercase))
# print(list(string.digits))
# ```
#
# __Suggestion: Use [pythex.org](https://pythex.org) to prototype the individual expressions.__

# %%
import string # imports the package called string 
print(list(string.ascii_lowercase)) # a list containing all lower case latters
print(list(string.ascii_uppercase)) # a list containing all lower case latters
print(list(string.digits)) # a list containing all digits

# %%
# your code here

# %% [markdown]
# # Task 4: List comprehension
# Assume the user is asked to input a number `n`. __Using list comprehension__, carry out the following tasks:
# * create the list `L = [1, ..., n]` (i.e., the list containing all numbers from `1` to `n`)
# * From `L` create the list `LL` of all squares `[1, 4, 9, ..., n*n]`
# * From `L`, create the list `LLL` of all numbers that have 9 as their last digit
# * create the list of tuples `(i, j)` such that both `i` and `j` are in `1` to `n`, i.e., `[(1,1), (1,2), ... (1,n),
# (2, 1), ..., (n, n)]`

# %%
# your code here

# %% [markdown]
# # Task 5.1: Lambda functions
# What is the following method doing? Try it out with `L = ["1", 2, 5, "4"]` and `g = lambda x:x**2`
# ```python
# def f(L, g):
#     return [g(g(x)) for x in L if type(x) == int]
# ```

# %%
# your code here

# %% [markdown]
# # 5.2 Lambda functions
# Let's say you are given a list of dictionaries such as `[{'name': 'Apple iphone', 'price': 12000}, {'name': 'Samsung galaxy', 'price': 8000}]` (add some more items if you want). Using a `lambda` function as key argument for sorted, sort the list by price in descending
# order.

# %%
# your code here
